# %% [markdown]
# ## Natural Language Analytics - Voulgari Eleni
#
# ### Exercise 1: Pre-processing
# #### Question A

# %% [markdown]
# Load libraries.

# %%
import os
import re
import nltk
import string
from urllib import urlopen
from nltk import FreqDist
from bs4 import BeautifulSoup
from collections import Counter
import html5lib
from nltk.corpus import stopwords
from nltk.util import ngrams

# %% [markdown]
# Load and read the html page.

# %%
url = "https://en.wikipedia.org/wiki/Artificial_neural_network"
html = urlopen(url).read()

# %% [markdown]
# Use of the library Beautiful Soup for pulling the data out of the HTML file.

# %%
pulled_data = BeautifulSoup(html, 'html5lib')
pulled_data
# Out:
# <!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en"><head>\n<meta charset="unicode-escape"/>\n<title>Artificial neural network - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Artificial_neural_network","wgTitle":"Artificial neural network","wgCurRevisionId":836490687,"wgRevisionId":836490687,"wgArticleId":21523,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: Explicit use of et al.","CS1 maint: Uses editors parameter","CS1 German-language sources (de)","CS1 maint: Uses authors parameter","Use dmy dates from June 2013","All articles with unsourced statements","Articles with unsourced statements from August 2017","Wikipedia articles needing clarification from April 2017","All Wikipedia articles needing clarification","Wikipedia articles needing clarification from January 2018","Wikipedia articles needing clarification from June 2017","Articles with unsourced statements from June 2017","Articles with unsourced statements from February 2017","Articles with unsourced statements from November 2014","Articles with excessive see also sections from March 2018","Computational statistics","Artificial neural networks","Classification algorithms","Computational neuroscience","Market research","Market segmentation","Mathematical psychology","Mathematical and quantitative methods (economics)"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Artificial_neural_network","wgRelevantArticleId":21523,"wgRequestId":"WtNZdApAICwAAD@wzjUAAABX","wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikibaseItemId":"Q192776","wgScoreNoteLanguages":{"arabic":"\u0627\u0644\u0639\u0631\u0628\u064a\u0629","catalan":"catal\xe0","deutsch":"Deutsch","english":"English","espanol":"espa\xf1ol","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"portugu\xeas","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.g ...

# %% [markdown]
# Remove the unnecessary tags of the html text, like "script", "mstyle" and "span", together with their content.
#
# The rest of the text, which is the part we need to work on, is taken with the help of get_text function of Beautiful Soup.

# %%
# Remove unnecessary things (scripts, styles, ...)
for tags in pulled_data(['script', 'mstyle', 'span']): 
    tags.decompose()

# Get the rest of the text
pulled_text = pulled_data.get_text()
pulled_text
# Out:
# u'\n\nArtificial neural network - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\nArtificial neural network\t\t\t\n\t\t\t\tFrom Wikipedia, the free encyclopedia\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\tJump to:\t\t\t\t\tnavigation, \t\t\t\t\tsearch\n\t\t\t\t\n\t\t\t\t"Neural network" redirects here. For other uses, see Neural network (disambiguation).\n\n\nMachine learning and\ndata mining\n\n\n\n\n\n\n\nProblems\n\n\n\nClassification\nClustering\nRegression\nAnomaly detection\nAutoML\nAssociation rules\nReinforcement learning\nStructured prediction\nFeature engineering\nFeature learning\nOnline learning\nSemi-supervised learning\nUnsupervised learning\nLearning to rank\nGrammar induction\n\n\n\n\n\n\n\n\n\n\nSupervised learning\n\n\n\n\n\nDecision trees\nEnsembles (Bagging, Boosting, Random forest)\nk-NN\nLinear regression\nNaive Bayes\nNeural networks\nLogistic regression\nPerceptron\nRelevance vector machine (RVM)\nSupport vector machine (SVM)\n\n\n\n\n\n\n\n\n\nClustering\n\n\n\nBIRCH\nCURE\nHierarchical\nk-means\nExpectation\u2013maximization (EM)\n\nDBSCAN\nOPTICS\nMean-shift\n\n\n\n\n\n\n\n\n\nDimensionality reduction\n\n\n\nFactor analysis\nCCA\nICA\nLDA\nNMF\nPCA\nt-SNE\n\n\n\n\n\n\n\n\n\nStructured prediction\n\n\n\nGraphical models (Bayes net, CRF, HMM)\n\n\n\n\n\n\n\n\n\nAnomaly detection\n\n\n\nk-NN\nLocal outlier factor\n\n\n\n\n\n\n\n\n\nNeural nets\n\n\n\nAutoencoder\nDeep learning\nMultilayer perceptron\nRNN\nRestricted Boltzmann machine\nSOM\nConvolutional neural network\n\n\n\n\n\n\n\n\n\nReinforcement learning\n\n\n\nQ-learning\nSARSA\nTemporal difference (TD)\n\n\n\n\n\n\n\n\n\nTheory\n\n\n\nBias-variance dilemma\nComputational learning theory\nEmpirical risk minimization\nOccam learning\nPAC learning\nStatistical learning\nVC theory\n\n\n\n\n\n\n\n\n\nMachine-learning venues\n\n\n\nNIPS\nICML\nML\nJMLR\nArXiv:cs.LG\n\n\n\n\n\n\n\n\n\nRelated articles\n\n\n\nList of datasets for machine-learning research\nOutline of machine learning\n\n\n\n\n\n\n\n\n\n Machine learning portal\n\n\n\n\n\n\n\nv\nt\ne\n\n\n\n\n\n\n\n\n\nAn artificial neural network is an interconnected group of nodes, akin to the vast network of neurons in a brain. Here, each circular node represents an artificial neuron and an arrow represents a connection from the output of one artificial neuron to the input of another.\n\n\nArtificial neural networks (ANNs) or connectionist systems are computing systems vaguely inspired by the biological neural networks that constitute animal brains.[1] Such systems "learn" (i.e. progressively improve performance on) tasks by considering examples, generally without task-specific programming. For example, in image recognition, they might learn to identify images that contain cats by analyzing example images that have been manually labeled as "cat" or "no cat" and using the results to identify cats in other images. They do this without any a priori knowledge about cats, e.g., that they have fur, tails, whiskers and cat-like faces. Instead, they evolve their own set of relevant characteristics from the learning material that they process.\nAn ANN is based on a collection of connected units or nodes called artificial neurons (a simplified version of biological neurons in an animal brain). Each connection (a simplified version of a synapse) between artificial neurons can transmit a signal from one to another. The artificial neuron that receives the signal can process it and then signal artificial neurons connected to it.\nIn common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is calculated by a non-linear function of the sum of its inputs. Artificial neurons and connections typically have a weight that adjusts as learning proceeds. The weight increases or decreases the strength of the signal at a connection. Artificial neurons may have a threshold such that only if the aggregate  ...

# %% [markdown]
# #### First Question - Word Count and Vocabulary of Web page

# %%
# Tokenize the text into list of words
tokens = nltk.word_tokenize(pulled_text)

# Convert to lower-case
tokens = [word.lower() for word in tokens]
print "Lower-cased tokens:", tokens    

# Remove punctuation and numbers
nonPunct = re.compile('.*[A-Za-z].*')
raw_words = [tok for tok in tokens if nonPunct.match(tok)]
# Out:
# Lower-cased tokens: [u'artificial', u'neural', u'network', u'-', u'wikipedia', u'artificial', u'neural', u'network', u'from', u'wikipedia', u',', u'the', u'free', u'encyclopedia', u'jump', u'to', u':', u'navigation', u',', u'search', u"''", u'neural', u'network', u"''", u'redirects', u'here', u'.', u'for', u'other', u'uses', u',', u'see', u'neural', u'network', u'(', u'disambiguation', u')', u'.', u'machine', u'learning', u'and', u'data', u'mining', u'problems', u'classification', u'clustering', u'regression', u'anomaly', u'detection', u'automl', u'association', u'rules', u'reinforcement', u'learning', u'structured', u'prediction', u'feature', u'engineering', u'feature', u'learning', u'online', u'learning', u'semi-supervised', u'learning', u'unsupervised', u'learning', u'learning', u'to', u'rank', u'grammar', u'induction', u'supervised', u'learning', u'decision', u'trees', u'ensembles', u'(', u'bagging', u',', u'boosting', u',', u'random', u'forest', u')', u'k-nn', u'linear', u'regression', u'naive', u'bayes', u'neural', u'networks', u'logistic', u'regression', u'perceptron', u'relevance', u'vector', u'machine', u'(', u'rvm', u')', u'support', u'vector', u'machine', u'(', u'svm', u')', u'clustering', u'birch', u'cure', u'hierarchical', u'k-means', u'expectation\u2013maximization', u'(', u'em', u')', u'dbscan', u'optics', u'mean-shift', u'dimensionality', u'reduction', u'factor', u'analysis', u'cca', u'ica', u'lda', u'nmf', u'pca', u't-sne', u'structured', u'prediction', u'graphical', u'models', u'(', u'bayes', u'net', u',', u'crf', u',', u'hmm', u')', u'anomaly', u'detection', u'k-nn', u'local', u'outlier', u'factor', u'neural', u'nets', u'autoencoder', u'deep', u'learning', u'multilayer', u'perceptron', u'rnn', u'restricted', u'boltzmann', u'machine', u'som', u'convolutional', u'neural', u'network', u'reinforcement', u'learning', u'q-learning', u'sarsa', u'temporal', u'difference', u'(', u'td', u')', u'theory', u'bias-variance', u'dilemma', u'computational', u'learning', u'theory', u'empirical', u'risk', u'minimization', u'occam', u'learning', u'pac', u'learning', u'statistical', u'learning', u'vc', u'theory', u'machine-learning', u'venues', u'nips', u'icml', u'ml', u'jmlr', u'arxiv', u':', u'cs.lg', u'related', u'articles', u'list', u'of', u'datasets', u'for', u'machine-learning', u'research', u'outline', u'of', u'machine', u'learning', u'machine', u'learning', u'portal', u'v', u't', u'e', u'an', u'artificial', u'neural', u'network', u'is', u'an', u'interconnected', u'group', u'of', u'nodes', u',', u'akin', u'to', u'the', u'vast', u'network', u'of', u'neurons', u'in', u'a', u'brain', u'.', u'here', u',', u'each', u'circular', u'node', u'represents', u'an', u'artificial', u'neuron', u'and', u'an', u'arrow', u'represents', u'a', u'connection', u'from', u'the', u'output', u'of', u'one', u'artificial', u'neuron', u'to', u'the', u'input', u'of', u'another', u'.', u'artificial', u'neural', u'networks', u'(', u'anns', u')', u'or', u'connectionist', u'systems', u'are', u'computing', u'systems', u'vaguely', u'inspired', u'by', u'the', u'biological', u'neural', u'networks', u'that', u'constitute', u'animal', u'brains', u'.', u'[', u'1', u']', u'such', u'systems', u'``', u'learn', u"''", u'(', u'i.e', u'.', u'progressively', u'improve', u'performance', u'on', u')', u'tasks', u'by', u'considering', u'examples', u',', u'generally', u'without', u'task-specific', u'programming', u'.', u'for', u'example', u',', u'in', u'image', u'recognition', u',', u'they', u'might', u'learn', u'to', u'identify', u'images', u'that', u'contain', u'cats', u'by', u'analyzing', u'example', u'images', u'that', u'have', u'been', u'manually', u'labeled', u'as', u'``', u'cat', u"''", u'or', u'``', u'no', u'cat', u"''", u'and', u'using', u'the', u'results', u'to', u'identify', u'cats', u'in', u'other', u'images', u'.', u'they', u'do', u'this', u'without', u'any', u'a', u'priori', u'knowledge', u'about', u'cats', u',', u'e.g.', u',', u'that', u'they', u'have', u'fur ...

# %%
# Count the total number of words in the text including stopwords
total_words = len(raw_words)
print "The total number of words is:", total_words, "\n"

# Use of the collections library and Counter module to produce the word count
word_count = Counter(raw_words)
print "The word count is shown below:\n", word_count
# Out:
# The total number of words is: 10743
#
# The word count is shown below:
# Counter({u'the': 560, u'of': 314, u'a': 296, u'and': 259, u'to': 235, u'in': 183, u'is': 154, u'neural': 150, u'learning': 123, u'that': 103, u'as': 101, u'networks': 101, u'network': 94, u'for': 93, u'by': 86, u'are': 80, u'with': 78, u'can': 65, u'be': 65, u'this': 64, u'from': 59, u'an': 59, u'function': 59, u'on': 58, u'machine': 49, u'or': 49, u'model': 47, u'deep': 47, u'computing': 46, u'input': 45, u'memory': 40, u'data': 40, u'it': 39, u'such': 37, u'layers': 35, u'cost': 35, u'output': 35, u'models': 34, u'recognition': 34, u'artificial': 33, u'used': 32, u'neurons': 30, u'architecture': 26, u'has': 26, u'other': 26, u'using': 25, u'algorithm': 25, u'have': 25, u'layer': 25, u'weights': 24, u'use': 24, u'which': 24, u'each': 23, u'was': 23, u'not': 23, u'processing': 23, u'they': 22, u'training': 22, u'backpropagation': 22, u'hidden': 21, u'one': 21, u'lstm': 21, u'where': 21, u'their': 21, u'unit': 20, u'these': 20, u'example': 19, u"'s": 19, u'given': 18, u'problem': 18, u'activation': 17, u'while': 17, u'systems': 17, u'anns': 17, u'form': 16, u'when': 16, u'representation': 16, u'only': 16, u'at': 16, u'also': 16, u'some': 16, u'control': 16, u'processor': 16, u'neuron': 16, u'units': 16, u'many': 15, u'through': 15, u'number': 15, u'parameters': 15, u'error': 15, u'isbn': 15, u'machines': 14, u'been': 14, u'tasks': 14, u'first': 14, u'than': 14, u'supervised': 14, u'biological': 14, u'information': 14, u'its': 14, u'set': 14, u'methods': 14, u'pattern': 14, u'functions': 14, u'distribution': 14, u'oclc': 13, u'may': 13, u'were': 13, u'called': 13, u'speech': 13, u'learned': 13, u'method': 13, u'trained': 13, u'more': 13, u'probability': 13, u'examples': 13, u'process': 13, u'based': 13, u'new': 12, u'classification': 12, u'over': 12, u'then': 12, u'time': 12, u'theory': 12, u'two': 12, u'research': 12, u'unsupervised': 12, u'optimization': 12, u'signal': 12, u'convolutional': 12, u'solution': 11, u'vector': 11, u'algorithms': 11, u'gradient': 11, u'no': 11, u'main': 11, u'ann': 11, u'connections': 11, u'between': 11, u'power': 11, u'large': 11, u'circuit': 11, u'task': 11, u'computational': 11, u'including': 11, u'class': 11, u'because': 11, u'dynamic': 10, u'turing': 10, u'types': 10, u'features': 10, u'logic': 10, u'connected': 10, u'learn': 10, u'how': 10, u'any': 10, u'article': 10, u'feedforward': 10, u'weight': 10, u'most': 10, u'into': 10, u'system': 10, u'regression': 10, u'even': 9, u'brain': 9, u'statistical': 9, u'variables': 9, u'all': 9, u'both': 9, u'simple': 9, u'analysis': 9, u'differentiable': 9, u'problems': 9, u'hardware': 9, u'but': 9, u'second': 8, u'would': 8, u'recurrent': 8, u'modeling': 8, u'short-term': 8, u'way': 8, u'particular': 8, u'graph': 8, u'level': 8, u'applications': 8, u'without': 8, u'components': 8, u'image': 8, u'nonlinear': 8, u'known': 8, u'science': 8, u'good': 8, u'distributed': 8, u'see': 8, u'uses': 8, u'step': 8, u'temporal': 8, u'auto': 8, u'matrix': 8, u'long': 8, u'depends': 8, u'computer': 8, u'hierarchical': 8, u'feature': 7, u'parallel': 7, u'linear': 7, u'however': 7, u'basic': 7, u'rnn': 7, u'often': 7, u'digital': 7, u'variable': 7, u'prediction': 7, u'commonly': 7, u'useful': 7, u'outputs': 7, u'following': 7, u'chip': 7, u'inputs': 7, u'natural': 7, u'group': 7, u'programming': 7, u'performance': 7, u'kernel': 7, u'filtering': 7, u'those': 7, u'rnns': 7, u'search': 7, u'perceptron': 7, u'register': 7, u'fully': 7, u'quantum': 7, u'introduction': 7, u'translation': 7, u'connection': 7, u'per': 7, u'similar': 7, u'defined': 7, u'results': 7, u'others': 7, u'addresses': 7, u'approaches': 7, u'management': 7, u'view': 7, u'architectures': 7, u'much': 7, u'cells': 7, u'reinforcement': 7, u'classifier': 6, u'created': 6, u'random': 6, u'terms': 6, u'decoder': 6, u'values': 6, u'policy': 6, u'simplified': 6, u'vision': 6, u'binary': 6, u'different': 6, u'same': 6, u'minimize': 6, u'conditional': 6, u'lamstar': 6, u'general': 6, u'original': 6, u'rate': 6, u'conv ...

# %%
# Use of FreqDist module to create the vocabulary of unique words of the Web page
vocabulary = nltk.probability.FreqDist(raw_words)

# Print the object, number of elements and the words of the vocabulary
print "The object of vocabulary is:", vocabulary, "\n"
print "The number of unique words is:", len(vocabulary), "\n"

print "The vocabulary is shown below:\n"
for word in vocabulary:
    print word
# Out:
# The object of vocabulary is: <FreqDist with 2700 samples and 10743 outcomes>
#
# The number of unique words is: 2700
#
# The vocabulary is shown below:
#
# limited
# two-dimensional
# hmms
# interference
# desirable
# borgelt
# al.cs1
# circuitry
# entropy
# consists
# neuro-fuzzy-systeme
# poorly
# whose
# calculate
# similarity
# exploding
# bias-variance
# endianness
# under
# worth
# updated
# risk
# downstream
# floating-point
# dynamic
# activation
# rise
# amorphous
# accelerator
# every
# updates
# namespaces
# classifications
# 9-bit
# task-specific
# vast
# networksclassification
# basics
# transduce
# solution
# broyden-fletcher-goldfarb-shanno
# vector
# ultra-low-voltage
# rprop
# sleep
# markov
# cmt
# 1940s
# commented
# specially
# disciplines
# concise
# hierarchical-deep
# estimates
# batch
# approximation
# second
# sarsa
# zisc
# estimated
# machines
# even
# employ
# errors
# max-pooling
# selected
# asic
# while
# reconstruction
# retrieved
# human-competitive
# new
# net
# asip
# simultaneously
# here
# reported
# protection
# represented
# wwn-1
# wwn-7
# digits
# property
# items
# k
# changed
# pdfprintable
# pooling
# menu
# permit
# calculators
# california
# pendeteksi
# suitable
# changes
# load-store
# york
# criticism
# appropriately
# projection
# classification
# wikimedia
# highly
# neutrons
# visible
# specifics
# total
# unit
# experimentation
# cybenko
# dna
# super-turing
# would
# found
# dnn
# therefore
# dns
# spike
# nisc
# type
# until
# vpu
# drawbacks
# b-type
# successful
# naive
# swar
# dpcn
# dirichlet
# feed-forward
# real-valued
# nodes
# must
# springer
# word
# mc
# ml
# mean-shift
# work
# neurons
# concepts
# backpropagated
# akin
# example
# stagnated
# indicated
# iterative
# unreadable
# organized
# discovery
# implementations
# oclc
# lstm-like
# guarantee
# 18-bit
# hoc
# provide
# travel
# feature
# discriminatively
# machine
# very
# adjacent
# significance
# gate
# multi-level
# poker
# abstraction
# turing
# after
# minimized
# lab
# risc
# non-executable
# curiosity
# retain
# minimizes
# parallel
# types
# effective
# rudolf
# schneider
# complexity
# algorithms
# correlation
# cpu-like
# operate
# order
# operations
# restriction
# recurrent
# fetus
# feedback
# over
# neuroevolution
# pascal
# nets
# non-convex
# before
# imc
# changescontact
# img
# auditory
# personal
# interaction
# writing
# better
# convexity
# bryson
# hidden
# easier
# overcome
# then
# them
# copying
# combination
# break
# they
# itanium
# one
# structural
# represents
# where-what
# grammar
# prostheses
# weng
# reasonably
# emphatic
# still-image
# arrow
# each
# closed-form
# classifier
# associative
# mean
# financial
# evolve
# weightless
# principles
# nostrand
# trading
# gating
# combining
# stream
# mdp
# extract
# array
# backgammon
# declaration
# network
# gradient
# restricted
# smt
# if-then
# dsp
# smp
# dsn
# adapt
# medicine
# millions
# 26-bit
# foundation
# numerical
# linear
# free
# standard
# ntm
# boosting
# estimate
# manycore
# enormous
# recovering
# created
# starts
# privacy
# days
# incorporated
# isa
# attribution-sharealike
# f33615-87-c-1499
# already
# features
# third-order
# coding
# primary
# rank
# synthesize
# adopted
# another
# mips
# clarity
# electronic
# timothy
# bottom-up
# similarly
# top
# nanodevices
# needed
# observations
# ranging
# rectifier
# jmlr
# serve
# lower
# rectified
# somewhat
# self-organizing
# peculiar
# begins
# height=
# target
# showed
# connectionist
# approximations
# scenes
# exclusive-or
# connectionism
# merck
# wiesel
# enables
# extracting
# fashion
# disambiguation
# modern
# mind
# talking
# manner
# emphasizing
# seen
# contents
# sub-symbolic
# dbms
# strength
# secure
# latter
# cope
# overtook
# chess
# transmit
# blue
# though
# object
# what
# anatomy
# boltzmann
# regular
# organization
# phase
# 4-bit
# mitigate
# flops
# observation
# 2013all
# medical
# flow
# dod
# principle
# section
# incomplete
# d.
# random
# solutions
# lstm
# latent
# just
# spite
# shuffling
# implementation
# situations
# delays
# arpa
# integrate
# gpu-based
# predecessor
# do
# mixture
# above
# wide
# de
# resilient
# christopher
# despite
# reconstruct
# runs
# covering
# excel
# microscopy
# bad
# architecture
# automatic
# linnainmaa
# out-performed
# captures
# electrodes
# habit
# w.
# simd
# emergent
# detection
# context-dependent
# result
# pa-risc
# microcode
# incorporating
# subject
# capacity
# tensor
# addison-wesley
# away
# wikipedia
# artificial
# symmetric
# score
# simplest
# farley
# perceptrons
# tolerance
# handwritten
# we
# terms
# lebiere
# however
# laureates
# modeling
# rows
# improve
# essentially
# non-connectionist
# biologically
# against
# layered
# games
# receives
# logic
# exceeds
# variance
# 20q
# sigmoidal
# recursive
# pregnancy
# conference
# 25-bit
# basis
# three
# been
# impeding
# replicate
# interest
# basic
# expected
# superhuman
# dynamically
# obtained
# graphical
# expectation–maximization
# drugs
# quantities
# catch
# worked
# sad
# applied
# occam
# n
# aim
# depictions
# aid
# voice
# d.o
# procedure
# economics
# print/export
# manipulators
# is
# it
# in
# comparative
# march
# µ-ssrbm
# trusted
# if
# containing
# descent
# credit
# perform
# border
# make
# cumulative
# geoscience
# complex
# potentially
# split
# several
# grows
# wheel
# independent
# published
# hand
# portal
# potentials
# many-layered
# unicore
# tune
# weakly
# maximizing
# black-box
# 1-bit
# ocean
# materials
# incapable
# simulated
# quantitative
# the
# paradigm
# mnist
# unified
# deepesns
# proposed
# sentence
# datapath
# assigned
# non-stationary
# identify
# transforms
# human
# anders
# yes
# succeeding
# previous
# visualization
# candidate
# instance
# had
# transformed
# board
# easy
# has
# rnn
# advances
# microcontroller
# multi-chip
# possible
# visible-hidden
# possibly
# boxes
# clustered
# depicts
# advanced
# apart
# performing
# specific
# informative
# steps
# sparse
# security
# cascade-correlation
# dean
# deal
# t-sne
# successfully
# helpabout
# statistic
# altered
# contests
# tutorial
# short-term
# input–output
# embodied
# for
# ica
# creative
# embodies
# cnn
# emitter-coupled
# neuroscientists
# core
# hyper-threading
# hsa
# minimization
# predicting
# constructive
# hubel
# properties
# takes
# zur
# limitation
# dnc
# bit-serial
# months
# o
# probabilities
# ensure
# connected
# suggestions
# nerve
# soc
# m.
# dilemma
# presence
# neurosciencemarket
# som
# encog
# down
# dreyfus
# coastal
# reducing
# mbr
# often
# wan
# 32-bit
# compression
# topologies
# support
# initial
# approximate
# schmidhuber
# way
# was
# synthesis
# lowest
# decoded
# form
# icml
# forming
# becoming
# encoder
# multiprocessor
# decoder
# encoded
# true
# over-specified
# trains
# pre-train
# ancestral
# devices
# cancers
# benchmarks
# 8-bit
# isij
# accelerate
# high-dimensional
# klawonn
# centralautologin/start
# computing
# abstract
# proven
# exist
# 33-bit
# de-noising
# distributions
# check
# uncorrupt
# no
# whereas
# when
# topped
# ng
# papert
# interested
# role
# cybernetics
# digital
# confusing
# shrink
# node
# 's
# models
# preceding
# update
# concurrent
# variable
# neuroscience
# hashing
# faster
# deng
# interval
# modules
# together
# reversible
# time
# push
# n3
# stacks
# 250p
# neighbors
# concept
# rom
# chain
# novelty
# particular
# alternatives
# type=1x1
# computation
# number-valued
# mill
# displaying
# layers
# inverse
# depend
# clarification
# graph
# werbos
# editors
# environment
# finally
# psoc
# analogous
# huma
# advantage
# choice
# stays
# solves
# level
# did
# quasi-newton
# solved
# team
# generatively
# multiprocessing
# prevent
# three-dimensional
# 2-bit
# prediction
# sign
# slowed
# cost
# wetware
# levenberg-marquardt
# pengadaan
# bagging
# resurgence
# adds
# electronics
# 2017all
# polak-ribiére
# large-vocabulary
# sequential
# template
# international
# acpi
# encoder–decoder
# palmer
# den
# tabulation
# denoising
# learn
# understanding
# tangent
# splice
# address
# teacher
# change
# incoming
# shift
# vectors
# commonly
# queue
# simultaneous
# domains
# resonance
# conveniently
# automaton
# navigation
# ipc
# tasks
# useful
# convolution
# extra
# uncorrupted
# modifying
# ips
# icdar
# traversing
# src=
# handled
# duda
# predictions
# 31-bit
# .created
# kordylewski
# https
# memory
# hinton
# selects
# theoretical
# today
# introducing
# wikipedia®
# fine-tuned
# outputs
# pipeline
# visual
# sentences
# cases
# auto-encoder
# valued
# bits
# local
# facilitating
# modified
# cat
# labeled
# values
# can
# following
# making
# modifies
# cisc
# nearest
# itemcite
# corrupted
# figure
# predict
# chip
# decoders
# agent
# sample
# performed
# allowed
# peptide
# regularization
# redundancy
# multiplexer
# watching
# chemical
# s.
# tdnn
# optimal
# absolute
# parameter
# inputs
# product
# designer
# irrational
# may
# max
# applications
# produce
# k-nn
# designed
# improving
# such
# data
# times
# tile
# natural
# outline
# beam
# explicit
# q
# cascade
# annealing
# so
# progressively
# representation
# gesture
# typical
# serving
# thresholds
# uncore
# brain
# lsu
# statistical
# ttl
# argued
# statements
# tta
# still
# pointer
# allow/require
# group
# how
# decreases
# forms
# platform
# offers
# policy
# main
# happened
# doi:10.1016/s0031-3203
# de-noised
# pruned
# squares
# views
# matches
# cross-entropy
# regarding
# noc
# scaling
# tails
# not
# hall
# maintaining
# matched
# term
# name
# january
# arrows
# h
# 36-bit
# em
# domain
# weighted
# significantly
# trade-offs
# directing
# gaussian
# challenges
# menggunakan
# operand
# et
# firmware
# 10-bit
# spiking
# disasters
# cryptoprocessor
# predefined
# emerges
# shown
# space
# furthermore
# squared
# increase
# attracted
# seriously
# investigation
# rational
# receiving
# sensor
# correct
# earlier
# theory
# million
# mechanisms
# possibility
# abdomen
# dependencies
# complicated
# bayes
# card
# fabric
# linkpage
# training
# fixed
# derivation
# language
# transition
# programming
# geomorphology
# first
# blind
# flying
# spoken
# omitted
# variables
# symbolic
# cpus
# nested
# simplified
# fast
# directly
# generative
# methodological
# message
# forwarding
# summarize
# size
# given
# necessarily
# categorical
# parametercs1
# structured
# filespecial
# kpca
# catastrophic
# initialized
# structures
# williams
# gives
# exploring
# mining
# that
# asymmetric
# brains
# continuous
# representing
# than
# relative
# impractical
# unfortunately
# gpgpu
# require
# ijcnn
# delay
# were
# and
# addressing
# eye-opening
# ann
# generalization
# cortexes
# slab
# any
# kevin
# subsystems
# computationally
# fpga
# efficient
# answering
# ideas
# note
# potential
# take
# online
# performance
# edited
# multiple
# normal
# buffer
# printed
# successive
# especially
# gradient-related
# considered
# average
# playing
# cortex
# typically
# drastically
# formal
# maint
# discovered
# netze
# threshold
# slow
# ensembles
# proportion
# written
# articledonate
# considerable
# algorithmscomputational
# only
# explicitly
# taxonomy
# ranking
# problem-specific
# murray
# prentice
# mixed-signal
# synapse
# resource
# held
# c++
# summary
# cochlea
# roger
# predicted
# mapped
# where
# vision
# doi:10.1016/0304-3975
# kernel
# sups
# parameteruse
# connections
# j.
# ways
# review
# hybrid
# label
# enough
# between
# affecting
# geometric
# august
# heterogeneous
# sparc
# dpcns
# article
# recall
# dates
# many
# region
# according
# contract
# called
# enabling
# propagation
# s
# aura
# fahlman
# expression
# nearby
# among
# filtering
# autoencoder
# cancer
# robotics
# venues
# sampling
# satisfaction
# sequence-processing
# learning
# associated
# considering
# tuning
# connectomics
# locally
# nynorskpolskiportuguêsromânăрусскийsimple
# combined
# العربيةazərbaycancabân-lâm-gúбългарскиbosanskicatalàčeštinadanskdeutscheestiελληνικάespañolesperantoeuskaraفارسیfrançaisgaeilge한국어հայերենहिन्दीhrvatskibahasa
# engine
# direction
# external
# photo-real
# bayesian
# baseband
# mimd
# those
# case
# stacked
# hdp
# these
# single
# 16-bit
# intimately
# diverse
# ongoing
# grundlagen
# interconnected
# lookaside
# coupled
# characteristics
# real-world
# bias
# hidden-hidden
# german-language
# technology
# binary
# different
# game-playing
# etc
# tour
# same
# pac
# speech
# arguments
# document
# events
# autonomously
# extended
# over-training
# arose
# changing
# invariance
# largely
# minimize
# roughly
# objection
# without
# solve
# components
# relied
# masks
# model
# cca
# researchers
# gates
# redirects
# minima
# being
# generally
# actions
# i/o
# relevant
# gated
# differentiation
# speed
# non-von-neumann
# feedforward
# heuristic
# bi-directional
# renewed
# secondly
# mother
# trigger
# seems
# improvement
# spmt
# samples
# momentum
# real
# multi-layer
# around
# rules
# decomposed
# early
# inhibition
# grid
# pop
# using
# execution
# mpsoc
# developers
# bhadeshia
# intel
# particle
# reduces
# unsourced
# serves
# t
# neuronal
# always
# output
# reduced
# grouping
# alternated
# conditional
# ppu
# competition
# calculated
# hand-designed
# table
# images
# million-fold
# wikipediacommunity
# matching
# provided
# memories
# recorded
# overly
# critical
# decomposition
# h.t
# provides
# semantically
# ni1000
# accessing
# scientific
# power
# equivalent
# fitness
# nmf
# content-addressable
# end-to-end
# drawn
# refers
# on
# central
# researchmarket
# of
# non-local
# practical
# 2x8
# supervised
# neighbor
# acyclic
# or
# cambridge
# unbounded
# image
# numerically
# back-side
# lamstar
# imitates
# operator
# layer-wise
# log
# area
# strictly
# there
# hazards
# cultured
# cats
# low
# series
# bubble
# diagnose
# complete
# tailored
# posterior
# gurney
# technologies
# trying
# with
# pull
# datasets
# applying
# pre-trained
# 2014articles
# robustness
# log-probability
# trips
# multiplications
# strongly
# ad
# videos
# ai
# certain
# hypercomputation
# al
# rvm
# general
# as
# senses
# at
# file
# formulation
# gradients
# bishop
# fill
# hart
# self-referential
# storage
# gpgpus
# multiclass
# prism
# valid
# spatial
# mathematics
# you
# kolmogorov-gabor
# poor
# portalrecent
# separate
# whiskers
# a.
# word-count
# attentional
# important
# recognise
# building
# cpi
# mask
# u
# parallelism
# original
# 50-bit
# represent
# all
# semantic
# consider
# lack
# 2017articles
# scalar
# cooperative
# reinhold
# implement
# alu
# accountlog
# semiconductor
# 3-dimensional
# rnns
# to
# program
# stochastic
# td
# baidu
# straightforward
# far
# scout
# changesupload
# aplikasi
# fall
# difference
# mpx
# heaven
# potentiation
# list
# applicable
# large
# adjust
# small
# biological
# rate
# design
# pass
# further
# attributable
# multiplier
# bilinear
# n't
# batch-mode
# nonlinear
# richard
# clock
# sum
# lawrence
# brief
# mmu
# version
# activations
# learned
# method
# 60-bit
# segmentation
# full
# christian
# component
# behaviour
# algoritma
# dimensionality
# i.e
# november
# mcclelland
# title=
# search
# rosenblatt
# disclaimers
# inspired
# losses
# allows
# experience
# prior
# amount
# base
# social
# action
# via
# followed
# mastering
# ctc-trained
# analyzing
# trained
# semi-supervised
# perceptron
# detecting
# select
# conventional
# discriminative
# distinct
# contains
# two
# automata
# automate
# taken
# entails
# more
# v850
# 'structural
# varying
# known
# none
# undirected
# science
# equation
# 2018wikipedia
# resources
# evolved
# v
# việt中文
# history
# compare
# needing
# mackay
# stacking
# share
# states
# minimum
# numbers
# sense
# phrase
# f.
# plausible
# information
# needs
# goal
# rather
# acts
# hdp-dbm
# maps
# machine-learning
# load/store
# ubiquitous
# w
# tsitsiklis
# derived
# mapping
# reflect
# connectivity
# tries
# preprocessing
# lighting
# numa
# response
# a
# sourcebook
# k-means
# register
# fundamental
# cs1
# retrieval
# help
# reservoir
# hierarchy
# developed
# cross
# radar
# through
# filters
# mini-batches
# its
# rapidly
# affine
# late
# detected
# systems
# travelling
# pca
# might
# deformation
# finer
# englishsuomisvenskaதமிழ்ไทยtürkçeукраїнськаاردوtiếng
# good
# motivated
# kohonen
# wikipediawikipedia
# propose
# framework
# february
# compound
# association
# instructions
# back-propagation
# fully
# kopplung
# 2d
# radial
# inherent
# characterized
# referred
# weight
# p
# generation
# energy
# reduce
# idea
# connect
# measurement
# quantum
# operation
# beyond
# event
# twists
# really
# discrete
# research
# induced
# lower-layer
# belief
# localization
# favored
# confidence
# difficulty
# 2-dimensional
# cookie
# members
# teach
# generate
# definition
# pairs
# thread
# e.g
# computers
# exponentially
# circuit
# corrupting
# major
# probability
# encoding
# relate
# misd
# misc
# number
# linking
# done
# dong
# stage
# passes
# differ
# heads
# alt=
# introduction
# leading
# interact
# least
# upper-layer
# stork
# swarm
# station
# statement
# scheme
# store
# too
# behind
# ssrbms
# mean-squared
# discover
# part
# shifter
# authors
# translation
# classifiers
# kind
# b
# determines
# instruction
# higher-order
# determined
# motivation
# higher-level
# randomly
# sontag
# neocognitron
# conjugate
# orders
# bookdownload
# robustly
# rochester
# zero
# depending
# speculative
# k.
# onset
# also
# empirically
# internal
# useless
# fletcher-reeves
# finding
# experienced
# multilingual
# most
# sponsored
# adder
# significant
# nothing
# alpha
# infrastructures
# probabilistic
# intervenes
# deviations
# unsupervised
# mobile
# tpm
# popularity
# mcm
# traditional
# tpu
# optical
# wasserman
# clean
# barrel
# physics
# particularly
# cs.lg
# converge
# minimizing
# relation
# hyped
# find
# backtracking
# contentcurrent
# access
# simulating
# parameters
# self-wires
# bisnis
# writer
# distributed
# adaline
# 1000-bit
# convoluted
# factor
# columns
# his
# notation
# dependent
# express
# trees
# style=
# devising
# during
# restart
# alexander
# arxiv
# remove
# crf
# common
# logistic
# x
# vincent
# iommu
# nas
# set
# art
# achieved
# intelligence
# achieves
# see
# individual
# are
# close
# arm
# analog
# project
# learns
# pagecontentsfeatured
# expert
# please
# smallest
# various
# numerous
# corruption
# available
# transistor–transistor
# sparsely
# initially
# attention
# spmd
# scalability
# //en.wikipedia.org/wiki/special
# vanishing
# interface
# interfaced
# both
# c
# paradigms
# last
# reverse
# license
# imparts
# link-weights
# connection
# became
# context
# long-term
# pdf
# multi-class
# whole
# component-based
# consume
# point
# simple
# logged
# corresponds
# simply
# schuppen
# belt
# kernels
# pp
# described
# transformations
# create
# due
# strategy
# pc
# reduction
# front-side
# powell-beale
# walter
# multi-thread
# top-down
# fire
# transferring
# gas
# precision
# modelling
# neumann
# vaguely
# determination
# southbridge
# assigning
# system-on-chip
# extracted
# handling
# fur
# look
# raw
# expanded
# 48-bit
# empirical
# mlp
# optimization
# behavior
# error
# engineers
# context-sensitive
# century
# von
# cleaned
# encountered
# itself
# aspects
# g.v
# belong
# shorten
# text-to-speech
# read
# reconstructed
# widely
# relatively
# composition
# higher
# used
# x86
# unlabeled
# comprehensive
# generalizes
# usually
# levels
# uses
# purpose
# birch
# aggregate
# robust
# stack
# expectation-maximization
# pre-training
# task
# database
# studies
# analysis
# edge
# systolic
# y
# traffic
# chemistry
# parametric
# grossly
# lda
# better-performing
# pillory
# simt
# competitive
# shape
# 'empirical
# amp
# inference
# alternative
# visible-visible
# wearable
# alignment
# 34-bit
# readers
# guaranteed
# signals
# source
# 128-bit
# location
# theorem
# relevance
# input
# transformation
# generalized
# apnea
# valueless
# evaluate
# couple
# unlimited
# deepening
# game
# dewdney
# bit
# projects
# like
# sorting
# cognitive
# pmu
# signal
# adiabatic
# yields
# popular
# mathematical
# google
# methods
# some
# back
# added
# examples
# classes
# delivered
# gradually
# scale
# affects
# decision
# transactions
# anns
# per
# competitions
# connecting
# preprocessors
# innovation
# epic
# either
# be
# run
# processing
# biophysical
# concatenated
# step
# width=
# pipelining
# re-order
# by
# superpositions
# cmac
# integers
# ill-defined
# rbms
# anything
# constraint
# optimized
# simulation
# sake
# range
# fpu
# extensions
# experiences
# block
# computational
# colorectal
# into
# within
# watt
# cpld
# next
# oldid=836490687
# clustering
# statistics
# spam
# multilayer
# governed
# mkm
# question
# amidst
# thirdly
# finite-state
# analyze
# sections
# opposed
# arise
# registered
# retina
# link
# repeatedly
# switchboard
# mse
# deployed
# directed
# circuits
# characteristic
# //en.wikipedia.org/w/index.php
# up
# differentiable
# deepdream
# preemptive
# continuously
# z
# similar
# rumelhart
# sometimes
# constant
# defined
# eet-8716324
# engineering
# cure
# superscalar
# metric
# defines
# encoders
# amounts
# priors
# siegelmann
# application
# priori
# coded
# demultiplexer
# tps
# arithmetic
# elements
# neurodynamic
# generates
# developmental
# benchmark
# problems
# polynomials
# generated
# allowing
# reservation
# depicting
# structure
# ago
# independently
# svm
# e
# algorithm
# required
# youtube
# risc-v
# notion
# depth
# implied
# weights
# ternary
# agu
# requires
# having
# once
# broaden
# laziness
# results
# illustrated
# j.c.
# go
# query
# issues
# cat-like
# compose
# graves
# isas
# concerned
# deterministic
# factoring
# languages
# helps
# hub5'00
# stable
# cluttered
# affine-sigmoid
# include
# sent
# hb
# labels
# implicitly
# ed.
# electron
# cellular
# bounding
# g.
# non-profit
# categories
# renaming
# entire
# magic
# uncovering
# notes
# ia-64
# fewer
# try
# registers
# neuromorphic
# optics
# noted
# cnns
# ann-learned
# jump
# video
# barang
# manipulating
# dynamics
# opaque
# giving
# indonesiaíslenskaitalianoעבריתქართულიlatinalietuviųmagyarмакедонскиmalagasyമലയാളം日本語norsknorsk
# habituation
# networks
# cell
# consistently
# secant
# microprocessor
# flowing
# delving
# 3d
# non-linear
# led
# degree
# respectively
# jointly
# 24-bit
# objects
# focused
# separation
# others
# implicit
# extreme
# receive
# involved
# adjusts
# resulting
# ivakhnenko
# ctc
# approximator
# gene
# makes
# composed
# sgx
# formulated
# addresses
# clark
# claim
# win
# tdsns
# scaled
# addressed
# boolean
# formulates
# motor
# apm
# apply
# tools
# analyses
# cloud
# relaying
# use
# from
# links
# space-unfolded
# morphogenesis
# nobel
# few
# depicted
# cache
# vehicle
# noisy
# convolutional
# formally
# sub-problem
# started
# mismatch
# train
# 22-bit
# disabling
# fpoa
# 1980s
# crosses
# integrating
# this
# challenge
# reproduce
# on/off
# proof
# control
# e.g.
# process
# high
# effectively
# assumptions
# multi-scale
# serial
# overfitting
# zero-copy
# regions
# located
# n-queens
# forest
# animal
# instead
# input-to-hidden-layer
# nips
# circular
# blocks
# outlier
# post–turing
# collection
# notebook
# hyper-parameter
# npu
# prostate
# efficiently
# 12-bit
# realized
# neuronaler
# two-layer
# lines
# correspond
# grbms
# processor
# advocates
# encyclopedia
# allow
# imagenet
# bipartite
# segmentationmathematical
# evolutionary
# sigmoid
# 256-bit
# interpreted
# hererelated
# including
# mentioned
# warren
# superior
# multi-dimensional
# brian
# chosen
# temporal
# combinational
# derivative
# 2017wikipedia
# multithreading
# defining
# tlb
# greater
# articulation
# auto
# dan
# material
# dock
# transparent
# successor
# articles
# masters
# university
# sufficiently
# magnitude
# l2
# softmax
# h.
# title=artificial_neural_network
# reproducing
# mcculloch
# determine
# map
# pitts
# related
# constitute
# frequency
# static
# variety
# measure
# our
# salesman
# special
# out
# maximizes
# dbscan
# matrix
# multi-stage
# integrates
# dsns
# performs
# maximized
# adaptive
# induction
# integrated
# red
# interactions
# hyperparameters
# ecl
# something-for-nothing
# greedy
# powerpc
# approaches
# tied
# philip
# backwards
# organic
# determining
# could
# feasible
# skin-surface
# explored
# time-varying
# quadratically
# facilitate
# pada
# isbi
# isbn
# matthias
# powerful
# 15-bit
# echo
# improvements
# hertz
# representations
# reached
# quality
# long
# management
# hyperbolic
# unknown
# system
# relations
# their
# memristor
# automl
# lapa
# programmable
# final
# non-parametric
# paved
# originating
# accompany
# fine-tuning
# shallow
# wiley
# simulate
# fuzzy
# oisc
# dynamical
# observed
# colleagues
# holland
# pointers
# depends
# limiting
# defense
# pagespermanent
# graupe
# counter
# robot
# have
# need
# kelley
# vieweg
# viewed
# documents
# marginalizing
# agency
# able
# accelerated
# mechanism
# contact
# mix
# thruster
# best
# which
# fifo
# techniques
# mit
# accuracy
# unless
# sisd
# who
# eight
# preliminary
# device
# comparison
# class
# 64-bit
# so-called
# plasticity
# doi:10.2355/isijinternational.39.966
# face
# mid-1980s
# continuous-valued
# mechanical
# normally
# no-prop
# gain
# dbm
# dbn
# text
# automated
# cross-validation
# purely
# high-level
# trivial
# minsky
# principal
# textual
# based
# knowledge
# produces
# q-learning
# jan
# won
# trainability
# molecules
# partially
# thousands
# achieve
# demonstrated
# handle
# means
# overall
# joint
# cerebellar
# words
# hebb
# gpus
# chips
# areas
# processes
# qr
# course
# upper
# approach
# jasa
# qa
# optimally
# ripley
# ciresan
# processed
# contain
# ssrbm
# cycles
# view
# predictive
# requirement
# constructing
# exists
# variations
# national
# module
# operates
# computes
# computer
# enhanced
# qth
# statistically
# closer
# superh
# pattern
# state
# identification
# routing
# invariant
# bunch
# textbook
# ability
# efficiency
# hypothesis
# general-purpose
# key
# dmy
# problem
# david
# egmont-petersen
# relu-function
# hydrology
# fuzzy-systemen
# taking
# equal
# agree
# april
# harvard
# eventsrandom
# estimation
# steinbrecher
# otherwise
# captioning
# adjusted
# unclear
# cc
# invasive
# distinguish
# sequences
# fukushima
# respect
# ucl
# electrocardiogram
# krogh
# i.e.
# addition
# trajectory
# trademark
# recognizers
# genetic
# slowly
# topology
# anomaly
# define
# arises
# corresponding
# eduardo
# ridder
# z/architecture
# neighbour
# hmm
# controller
# deep
# improved
# an
# novel
# unlike
# dataflow
# value
# choices
# will
# frameworks
# rbm
# reliability
# handwriting
# dbns
# jeanette
# layer
# vc
# manually
# almost
# neuron
# thus
# site
# surface
# hardware
# vs
# turns
# claimed
# regression
# finance
# capture
# embodiments
# informationwikidata
# parts
# units
# android
# finite
# propagate
# infer
# difficult
# bertsekas
# clarificationwikipedia
# unconventional
# faces
# upon
# functions
# architectures
# coprocessor
# infinite
# frequently
# identity
# nx
# neural
# gmdh
# modeled
# well
# thought
# patterns
# backpropagation
# processor/dma
# sets
# firstly
# position
# muscle
# inc.
# excessive
# less
# compel
# accurate
# sources
# stored
# 40-bit
# voltage
# glue
# low-level
# elliot
# clipper
# density
# smith
# capabilities
# mathematically
# synaptic
# increased
# behnke
# element-wise
# proses
# spike-and-slab
# increases
# out-of-order
# unseen
# 512-bit
# press
# o.
# variants
# loss
# necessary
# helpful
# lost
# extremely
# controllers
# single-layer
# become
# works
# page
# because
# sequence
# handels
# convex
# hebbian
# peter
# recognition
# psychologymathematical
# parallelization
# broad
# avoid
# miner
# reconfigurable
# instantaneous
# e-mail
# does
# random-access
# assuming
# hengzhi
# capability
# non-analytical
# mode
# hinder
# biology
# noise
# multi-core
# selecting
# künstlicher
# clarendon
# although
# offset
# approximating
# simpler
# about
# actual
# extension
# freedom
# certainty
# dependence
# dnn-based
# dependency
# introduced
# commons
# predictor
# software
# 39-bit
# discretization
# own
# twenty-first
# functional
# dataset
# intalkcontributionscreate
# guard
# k-nearest
# lung
# additions
# fraud
# forget
# kruse
# 27-bit
# single-core
# van
# additional
# geoffrey
# vax
# much
# moewes
# inspiration
# flynn
# naturally
# function
# bridgman
# statementsarticles
# aircraft
# bus
# but
# hierarchical
# ho
# larger
# convergence
# hd
# he
# count
# made
# compute
# switch
# wish
# cells
# smooth
# reinforcement
# placed
# haykin
# steepest
# demonstrate
# distribution
# situ
# recognize
# universal
# life
# eu
# periods
# microblaze
# proceeds
# cmos
# deeper
# mutual
# contest
# virtual
# other
# branch
# mass
# kinds
# june
# ultimately
# covariance
# fundamentally
# simon
# northbridge
# factors
# statisticsartificial
# rule
# cpu
# write
# diagnosis
# vliw
# validation
# augmented

# %% [markdown]
# #### Second Question - Sentences

# %%
# Use of the sent_tokenize module to find the number of sentences
sentences = nltk.tokenize.sent_tokenize(pulled_text)
print "The number of sentences is:", len(sentences)
# Out:
# The number of sentences is: 565

# %% [markdown]
# #### Third Question - Lexical Diversity
#
# Lexical diversity refers to the variety of words used in a text. It generally measures the number of unique words occurring in a text by the number of tokens.

# %%
# Find the lexical diversity by dividing the number of unique words by the number of total words
diversity = len(vocabulary) / float(total_words)
print "The lexical diversity is:", diversity
# Out:
# The lexical diversity is: 0.251326445127

# %% [markdown]
# #### Fourth Question  - 5 Most Common Lexical Categories (parts of speech)
#
# To find the 5 most common lexical categories we perform part-of-speech tagging which is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech.

# %%
# Use of pos_tag module to perform POS tagging
part_of_speech_tag = nltk.pos_tag(raw_words)

# Make a list of the part-of-speech tags
pos_tags = [pos for (word, pos) in part_of_speech_tag]

# Find and print the part-of-speech tags which appear mostly in the above list
five_common = nltk.FreqDist(pos_tags).most_common(5)
print five_common
# Out:
# [('NN', 2759), ('JJ', 1632), ('IN', 1202), ('DT', 1094), ('NNS', 931)]

# %% [markdown]
# #### Fifth Question - 10 Most Common Unigrams - 10 Most Common Bigrams
#
# An n-gram is a contiguous sequence of n items from a given sample of text or speech. So in the case of the unit being a word, a unigram is a word and a bigram is a sequence of two words.

# %%
# Remove the stop words of English, using the nltk.corpus.stopwords('english') list
filtered_words = [word for word in raw_words if word not in stopwords.words('english')]

# Use of the ngrams and Counter modules to create the unigrams and bigrams and then find the 10 most common
unigrams = ngrams(filtered_words,1)
ten_unigrams = Counter(unigrams).most_common(10)
print "The 10 unigrams are:", ten_unigrams
print "\n"

bigrams = ngrams(filtered_words,2)
ten_bigrams = Counter(bigrams).most_common(10)
print "The 10 bigrams are:", ten_bigrams
# Out:
# The 10 unigrams are: [((u'neural',), 150), ((u'learning',), 123), ((u'networks',), 101), ((u'network',), 94), ((u'function',), 59), ((u'machine',), 49), ((u'model',), 47), ((u'deep',), 47), ((u'computing',), 46), ((u'input',), 45)]
#
#
# The 10 bigrams are: [((u'neural', u'networks'), 68), ((u'neural', u'network'), 50), ((u'artificial', u'neural'), 19), ((u'machine', u'learning'), 17), ((u'deep', u'learning'), 15), ((u'cost', u'function'), 15), ((u'isbn', u'oclc'), 13), ((u'pattern', u'recognition'), 11), ((u'activation', u'function'), 9), ((u'main', u'article'), 9)]

# %% [markdown]
# If we have stemmed the words, which means that we would do the process of reducing inflected (or sometimes derived) words to their word stem, base or root form — generally a written word form, the words "networks" and "network" would appear once as a stem.

# %% [markdown]
# #### Sixth Question - Number of Nouns in the Page

# %%
# Make a list of words that are tagged as nouns in the process of part-of-speech tagging
nouns = [word for (word, pos) in part_of_speech_tag if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
print "The number of nouns is:", len(nouns)
# Out:
# The number of nouns is: 3700
